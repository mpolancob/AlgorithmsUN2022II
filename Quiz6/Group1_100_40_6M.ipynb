# %% [markdown]
# <a href="https://colab.research.google.com/github/mpolancob/AlgorithmsUN2022II/blob/main/Quiz6/Group1_100_40_6M.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q18 Quick Start
#
# This template shows you the basic steps for taking part to the **Q18 NASDAQ-100 Stock Long-Short contest**.

# %%
import xarray as xr
import pandas as pd
import qnt.ta as qnta
import qnt.data as qndata
import qnt.output as qnout
import qnt.stats as qns

data = qndata.stocks.load_ndx_data(min_date="2022-04-13")

close     = data.sel(field="close")
is_liquid = data.sel(field="is_liquid")
sma_slow  = qnta.sma(close, 100)
sma_fast  = qnta.sma(close, 40)
weights   = xr.where(sma_slow < sma_fast, 1, -1)
weights   = weights * is_liquid

weights = qnout.clean(weights, data, "stocks_nasdaq100")

# calc stats
stats = qns.calc_stat(data, weights.sel(time=slice("2022-04-13", None)))
display(stats.to_pandas().tail())

# graph
performance = stats.to_pandas()["equity"]
import qnt.graph as qngraph

qngraph.make_plot_filled(performance.index, performance, name="PnL (Equity)", type="log")
# Out:
# fetched chunk 1/1 0s
# Data loaded 0s
# Output cleaning...
# fix uniq
# ffill if the current price is None...
# Check liquidity...
# Ok.
# Check missed dates...
# Ok.
# Normalization...
# Output cleaning is complete.
# field         equity  relative_return  volatility  underwater  max_drawdown  \
# time
# 2022-10-07  0.993925         0.005395    0.276549   -0.115008     -0.187871
# 2022-10-10  0.997602         0.003699    0.275479   -0.111734     -0.187871
# 2022-10-11  0.998462         0.000862    0.274377   -0.110968     -0.187871
# 2022-10-12  0.997693        -0.000770    0.273289   -0.111653     -0.187871
# 2022-10-13  0.989161        -0.008552    0.272482   -0.119250     -0.187871
#
# field       sharpe_ratio  mean_return      bias  instruments  avg_turnover  \
# time
# 2022-10-07     -0.044688    -0.012358 -0.078431        102.0      0.052222
# 2022-10-10     -0.017602    -0.004849 -0.137255        102.0      0.052455
# ...

# %%
weights = weights.sel(time=slice("2022-04-13",None))

qnout.check(weights, data, "stocks_nasdaq100")
# Out:
# Check liquidity...
# Ok.
# Check missed dates...
# Ok.
# Check the sharpe ratio...
# WARNING! There are not enough points in the data
# The first point(2022-04-13) should be earlier than 2006-01-01
# Load data more historical data.
# WARNING! There are not enough points in the output.
# The output series should start from 2006-01-01 or earlier instead of 2022-04-13
# Period: 2022-04-13 - 2022-10-13
# Sharpe Ratio = -0.07820457661246207
# ERROR! The Sharpe Ratio is too low. -0.07820457661246207 < 1
# Improve the strategy and make sure that the in-sample Sharpe Ratio more than 1.
# Check correlation.
#
# Ok. This strategy does not correlate with other strategies.
